# %% [markdown]
# すべての m, bをプロットし、ばらつきを見てみる

# %%
import sys
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sympy import *

# my module
current_dir = os.getcwd()
sys.path.append(os.path.join(current_dir, '../'))
import calc_BVI

# %%
input_folderpath = r"C:\Users\02217013\Documents"
input_filename = "calliance1_nmr.csv"

# irreducible conditionのときのPc とりあえずPsiで構わん（というか統一してあれば単位何でもいい）
the_Pci = 50

# newton法をすたーとするx, m, bの値
x0 = 1000

m0 = 0.055
b0 = 1

# default cutoff値
C = 33

# %%
input_file = os.path.join(input_folderpath, input_filename)
the_df = pd.read_csv(input_file)
m_list, b_list, optimized_m, optimized_b = calc_BVI.m_b_spectral_empirical(the_df, m0, b0)

fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(m_list, b_list)
# ax1.set_xlim(-30, 30)
# ax1.set_ylim(-30, 30)
plt.show()
# Out:
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df.Swi[df.Swi > 1] = 1
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df.Swi[df.Swi < 0] = 0
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df.Swi_dm[df.Swi > 1] = 0
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df.Swi_dm[df.Swi < 0] = 0
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df.Swi_db[df.Swi > 1] = 0
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df.Swi_db[df.Swi < 0] = 0
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py:1943: RuntimeWarning: overflow encountered in true_divide
#   s = divide(1, s, where=large, out=s)
# break! k1=Calliance_1_142, k2=Calliance_1_143, m=nan, b=nan, count=9
# break! k1=Calliance_1_142, k2=Calliance_1_148, m=0.03695695651190374, b=1.090001867259825, count=0
# break! k1=Calliance_1_142, k2=Calliance_1_22, m=0.03689007402805366, b=1.091713960903085, count=0
# break! k1=Calliance_1_142, k2=Calliance_1_225, m=0.061636283881507326, b=-0.11694870045139472, count=1
# break! k1=Calliance_1_142, k2=Calliance_1_230, m=0.08813599207109357, b=-0.1861750351755333, count=1
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:185: RuntimeWarning: overflow encountered in square
#   diff = np.sqrt(np.sum((var_array - next_var_array) ** 2))
# break! k1=Calliance_1_142, k2=Calliance_1_239, m=-1.9130972515666315e+287, b=3.8016966156973105e+287, count=9
# break! k1=Calliance_1_142, k2=Calliance_1_24, m=0.03813915620918799, b=1.1535425934301669, count=1
# break! k1=Calliance_1_142, k2=Calliance_1_270, m=0.021234579108194436, b=1.6577018281929612, count=1
# break! k1=Calliance_1_142, k2=Calliance_1_275, m=-1.1778026603417626e+218, b=1.1778026602777911e+219, count=11
# break! k1=Calliance_1_142, k2=Calliance_1_28, m=0.02968317082860024, b=1.4142267797234445, count=1
# break! k1=Calliance_1_142, k2=Calliance_1_282, m=-2.744091585081798e+235, b=-1.0932635797138637e+234, count=9
# break! k1=Calliance_1_142, k2=Calliance_1_304, m=-2.6951492541437167e+228, b=6.665664440987845e+228, count=10
# break! k1=Calliance_1_142, k2=Calliance_1_347, m=-4.0125259783851606e+219, b=8.779915931330266e+218, count=8
# break! k1=Calliance_1_142, k2=Calliance_1_356, m=-0.0028061528396092217, b=0.7948171073675921, count=6
# break! k1=Calliance_1_142, k2=Calliance_1_371, m=0.07403502577125179, b=0.16525630728253282, count=1
# break! k1=Calliance_1_142, k2=Calliance_1_419, m=0.05315700652780063, b=0.5749909964936648, count=2
# break! k1=Calliance_1_142, k2=Calliance_1_441, m=-2.650077867578711e+263, b=2.423727653475472e+263, count=12
# break! k1=Calliance_1_142, k2=Calliance_1_52, m=-0.07838213999430435, b=3.991206774827596, count=6
# break! k1=Calliance_1_142, k2=Calliance_1_53, m=-3.3308456544828967e+199, b=3.3308434732226596e+201, count=11
# break! k1=Calliance_1_143, k2=Calliance_1_148, m=0.06738708605028555, b=0.5899301469535021, count=1
# break! k1=Calliance_1_143, k2=Calliance_1_22, m=0.05628971349870458, b=0.9363287383368041, count=0
# break! k1=Calliance_1_143, k2=Calliance_1_225, m=0.04249345920140425, b=1.332320973015759, count=1
# break! k1=Calliance_1_143, k2=Calliance_1_230, m=0.07855385428724969, b=0.42643759053751806, count=2
# break! k1=Calliance_1_143, k2=Calliance_1_239, m=-1.6779303123005752e+205, b=3.0230980793021455e+203, count=9
# break! k1=Calliance_1_143, k2=Calliance_1_24, m=0.050103874935061646, b=1.0882577729351885, count=0
# break! k1=Calliance_1_143, k2=Calliance_1_270, m=0.047502505855856365, b=1.1713601977810688, count=1
# break! k1=Calliance_1_143, k2=Calliance_1_275, m=190920622.2896141, b=-956512317.6693033, count=7
# break! k1=Calliance_1_143, k2=Calliance_1_28, m=0.055097901865548936, b=0.9656005644579544, count=0
# break! k1=Calliance_1_143, k2=Calliance_1_282, m=3.2197158386380755e+156, b=-3.687655213856602e+156, count=9
# break! k1=Calliance_1_143, k2=Calliance_1_304, m=1.3787802070516477e+200, b=-2.1949737215857316e+201, count=9
# break! k1=Calliance_1_143, k2=Calliance_1_347, m=3.2291782780267275e+267, b=-8.11322133666412e+266, count=8
# break! k1=Calliance_1_143, k2=Calliance_1_356, m=0.06472521773930041, b=0.5537105281939687, count=4
# break! k1=Calliance_1_143, k2=Calliance_1_371, m=0.05115414708211584, b=1.0624622673257527, count=0
# break! k1=Calliance_1_143, k2=Calliance_1_419, m=-0.01742761089951059, b=0.05476693144125042, count=2
# break! k1=Calliance_1_143, k2=Calliance_1_441, m=-8.431042074825804e+280, b=4.223952079431545e+282, count=12
# break! k1=Calliance_1_143, k2=Calliance_1_52, m=38642006.05954415, b=-193596450.35620844, count=8
# break! k1=Calliance_1_143, k2=Calliance_1_53, m=-2.5997435957164203e+172, b=-1.29987179785821e+171, count=13
# break! k1=Calliance_1_148, k2=Calliance_1_22, m=0.036790483798103644, b=1.0925116484100938, count=0
# break! k1=Calliance_1_148, k2=Calliance_1_225, m=0.055240419661951055, b=0.8066301888457603, count=1
# break! k1=Calliance_1_148, k2=Calliance_1_230, m=0.07479304444233244, b=0.5220494564966288, count=1
# break! k1=Calliance_1_148, k2=Calliance_1_239, m=1.4371424981214784e+198, b=-7.202631037268723e+198, count=12
# break! k1=Calliance_1_148, k2=Calliance_1_24, m=0.03449511838818009, b=1.1734318173869647, count=1
# break! k1=Calliance_1_148, k2=Calliance_1_270, m=17031140.58733328, b=-170311405.86025345, count=8
# break! k1=Calliance_1_148, k2=Calliance_1_275, m=0.1387730374206424, b=-0.07543562289872949, count=2
# break! k1=Calliance_1_148, k2=Calliance_1_28, m=0.007821335538330868, b=-0.054480088726201914, count=3
# break! k1=Calliance_1_148, k2=Calliance_1_282, m=0.19812150231376485, b=-1.3812727213843417, count=1
# break! k1=Calliance_1_148, k2=Calliance_1_304, m=0.14161844253236916, b=-0.05192595400649799, count=1
# break! k1=Calliance_1_148, k2=Calliance_1_347, m=2.844649407729227e+230, b=-8.989092249285172e+230, count=13
# break! k1=Calliance_1_148, k2=Calliance_1_356, m=-3.4160482765838953e+159, b=1.0805828365212886e+159, count=9
# break! k1=Calliance_1_148, k2=Calliance_1_371, m=0.05919700009927017, b=0.7485226605621739, count=1
# break! k1=Calliance_1_148, k2=Calliance_1_419, m=-1.6043919811564705e+189, b=1.2738649172205257e+189, count=12
# break! k1=Calliance_1_148, k2=Calliance_1_441, m=0.024963989858215956, b=1.3785217235887548, count=4
# break! k1=Calliance_1_148, k2=Calliance_1_52, m=0.05886582609608061, b=0.7566156860460531, count=2
# break! k1=Calliance_1_148, k2=Calliance_1_53, m=225306.9893675595, b=-1128788.0134405724, count=6
# break! k1=Calliance_1_22, k2=Calliance_1_225, m=0.05069404038413915, b=0.9811483811776064, count=0
# break! k1=Calliance_1_22, k2=Calliance_1_230, m=0.06346495787874595, b=0.8767599511499186, count=1
# break! k1=Calliance_1_22, k2=Calliance_1_239, m=0.23715430795815273, b=-0.4478355233547809, count=3
# break! k1=Calliance_1_22, k2=Calliance_1_24, m=0.022956529895718978, b=1.2404099123347245, count=1
# break! k1=Calliance_1_22, k2=Calliance_1_270, m=0.06884318942855878, b=0.8314069935741185, count=1
# break! k1=Calliance_1_22, k2=Calliance_1_275, m=0.1169619887930059, b=0.44814413140138876, count=2
# break! k1=Calliance_1_22, k2=Calliance_1_28, m=0.05765526928860968, b=0.9253910510327648, count=0
# break! k1=Calliance_1_22, k2=Calliance_1_282, m=0.04760011010350773, b=0.8087423893424273, count=2
# break! k1=Calliance_1_22, k2=Calliance_1_304, m=0.11062478737813494, b=0.4804182583895437, count=2
# break! k1=Calliance_1_22, k2=Calliance_1_347, m=-2.8989548763937327e+271, b=-5.786337078630207e+270, count=10
# break! k1=Calliance_1_22, k2=Calliance_1_356, m=0.14173272405166165, b=0.28039520816179453, count=2
# break! k1=Calliance_1_22, k2=Calliance_1_371, m=0.053607843499468386, b=0.9578097028338811, count=0
# break! k1=Calliance_1_22, k2=Calliance_1_419, m=0.015541790162763046, b=1.3098031780554504, count=1
# break! k1=Calliance_1_22, k2=Calliance_1_441, m=0.02128478064824394, b=1.2507859694564476, count=1
# break! k1=Calliance_1_22, k2=Calliance_1_52, m=0.05120418552591459, b=0.9770622734684499, count=0
# break! k1=Calliance_1_22, k2=Calliance_1_53, m=0.08382306838884226, b=0.7073541209631042, count=1
# break! k1=Calliance_1_225, k2=Calliance_1_230, m=0.08869614248076436, b=-0.20606011946834646, count=1
# break! k1=Calliance_1_225, k2=Calliance_1_239, m=-8402.601060157127, b=334423.5472938826, count=4
# break! k1=Calliance_1_225, k2=Calliance_1_24, m=0.047649731615366946, b=1.104944331430235, count=1
# break! k1=Calliance_1_225, k2=Calliance_1_270, m=0.04503483520456146, b=1.2141265847414702, count=1
# break! k1=Calliance_1_225, k2=Calliance_1_275, m=-9.249620372380024e+303, b=-4.624810186190011e+302, count=11
# break! k1=Calliance_1_225, k2=Calliance_1_28, m=0.04748941195541314, b=1.085228926979626, count=0
# break! k1=Calliance_1_225, k2=Calliance_1_282, m=-9.412048050986822e+252, b=-1.1853964799731516e+251, count=8
# break! k1=Calliance_1_225, k2=Calliance_1_304, m=-38861.19683610394, b=1546675.6579134953, count=4
# break! k1=Calliance_1_225, k2=Calliance_1_347, m=-0.01683570360269771, b=1.0551026904777816, count=6
# break! k1=Calliance_1_225, k2=Calliance_1_356, m=-6.647634848733213e+299, b=1.907425577470333e+299, count=21
# break! k1=Calliance_1_225, k2=Calliance_1_371, m=0.07076407391975091, b=0.3293903296318489, count=3
# break! k1=Calliance_1_225, k2=Calliance_1_419, m=0.03446193700559141, b=0.67386612205545, count=2
# break! k1=Calliance_1_225, k2=Calliance_1_441, m=5.387747906726461e+227, b=-1.7037554540175079e+229, count=8
# break! k1=Calliance_1_225, k2=Calliance_1_52, m=0.04984474410133467, b=1.008731991142977, count=0
# break! k1=Calliance_1_225, k2=Calliance_1_53, m=0.032261865679767285, b=2.0631990992506783, count=2
# break! k1=Calliance_1_230, k2=Calliance_1_239, m=-0.019403487504579806, b=9.55183937351607, count=9
# break! k1=Calliance_1_230, k2=Calliance_1_24, m=0.05884040242321427, b=1.0479001623172675, count=0
# break! k1=Calliance_1_230, k2=Calliance_1_270, m=0.06113660317338524, b=0.9463620632424686, count=0
# break! k1=Calliance_1_230, k2=Calliance_1_275, m=-680907504.9136131, b=54064055890.3246, count=5
# break! k1=Calliance_1_230, k2=Calliance_1_28, m=0.06516593149174373, b=0.8162764828660964, count=1
# break! k1=Calliance_1_230, k2=Calliance_1_282, m=5.6916020543852754e+274, b=-1.428592196811861e+277, count=14
# break! k1=Calliance_1_230, k2=Calliance_1_304, m=0.07421547089922664, b=-2.463870362450163, count=4
# break! k1=Calliance_1_230, k2=Calliance_1_347, m=-5.672331266154655e+168, b=1.2037570923049134e+168, count=14
# break! k1=Calliance_1_230, k2=Calliance_1_356, m=0.055692385768606426, b=1.2102804375257858, count=1
# break! k1=Calliance_1_230, k2=Calliance_1_371, m=11119245.362064347, b=-351621405.7297804, count=5
# break! k1=Calliance_1_230, k2=Calliance_1_419, m=0.08748900018205258, b=0.09553476381611448, count=1
# break! k1=Calliance_1_230, k2=Calliance_1_441, m=-8.539322499285988e+290, b=-3.3995655612793587e+289, count=12
# break! k1=Calliance_1_230, k2=Calliance_1_52, m=0.08406809093711393, b=0.27384874896513006, count=2
# break! k1=Calliance_1_230, k2=Calliance_1_53, m=0.05476774307652693, b=1.257477998369905, count=1
# break! k1=Calliance_1_239, k2=Calliance_1_24, m=0.23495871573073207, b=0.3455038090204754, count=3
# break! k1=Calliance_1_239, k2=Calliance_1_270, m=0.15263666050113167, b=-0.39388373539809046, count=1
# break! k1=Calliance_1_239, k2=Calliance_1_275, m=-6.459069220143721e+225, b=8.083579477213571e+225, count=16
# break! k1=Calliance_1_239, k2=Calliance_1_28, m=0.17400023162080872, b=-0.5644879814818127, count=1
# break! k1=Calliance_1_239, k2=Calliance_1_282, m=0.11659447739616757, b=1.296413869912119, count=1
# break! k1=Calliance_1_239, k2=Calliance_1_304, m=-3416392476.0593376, b=135972420547.18176, count=5
# break! k1=Calliance_1_239, k2=Calliance_1_347, m=0.13336605226127193, b=-0.7765876578850885, count=1
# break! k1=Calliance_1_239, k2=Calliance_1_356, m=0.15512746088363635, b=-0.20534168851208978, count=1
# break! k1=Calliance_1_239, k2=Calliance_1_371, m=3366217.0662929052, b=-424143350.97630817, count=13
# break! k1=Calliance_1_239, k2=Calliance_1_419, m=-292302.87164488615, b=2321844.169227603, count=9
# break! k1=Calliance_1_239, k2=Calliance_1_441, m=-1.9670380679239118e+297, b=2.971949991870595e+297, count=10
# break! k1=Calliance_1_239, k2=Calliance_1_52, m=206041.16929461545, b=-3255450.467627802, count=4
# break! k1=Calliance_1_239, k2=Calliance_1_53, m=144212.78961711956, b=-573966.9004789762, count=7
# break! k1=Calliance_1_24, k2=Calliance_1_270, m=0.053177087010698745, b=1.07406134346558, count=0
# break! k1=Calliance_1_24, k2=Calliance_1_275, m=0.07993588067244617, b=0.9504514794011047, count=0
# break! k1=Calliance_1_24, k2=Calliance_1_28, m=0.04621229438347119, b=1.1121253880736113, count=1
# break! k1=Calliance_1_24, k2=Calliance_1_282, m=-1.748017479099334e+184, b=3.713658578808919e+183, count=12
# break! k1=Calliance_1_24, k2=Calliance_1_304, m=0.07639966334621118, b=0.9667867203885643, count=0
# break! k1=Calliance_1_24, k2=Calliance_1_347, m=0.08931400545668472, b=0.9071300672173944, count=0
# break! k1=Calliance_1_24, k2=Calliance_1_356, m=0.06523232736624804, b=1.0183732343358984, count=0
# break! k1=Calliance_1_24, k2=Calliance_1_371, m=0.05060345023310467, b=1.0859500293402542, count=0
# break! k1=Calliance_1_24, k2=Calliance_1_419, m=0.019295443957825967, b=1.2583537189230682, count=1
# break! k1=Calliance_1_24, k2=Calliance_1_441, m=0.02200796763047818, b=1.2422903304109025, count=1
# break! k1=Calliance_1_24, k2=Calliance_1_52, m=0.046416515722377386, b=1.1110897771490031, count=1
# break! k1=Calliance_1_24, k2=Calliance_1_53, m=0.06550837457223671, b=1.017098058853813, count=0
# break! k1=Calliance_1_270, k2=Calliance_1_275, m=-0.006311049055574217, b=2.3920624579116194, count=4
# break! k1=Calliance_1_270, k2=Calliance_1_28, m=61286641.87742771, b=-612866418.761343, count=8
# break! k1=Calliance_1_270, k2=Calliance_1_282, m=0.18560378519438891, b=-1.0819118876322853, count=1
# break! k1=Calliance_1_270, k2=Calliance_1_304, m=0.08959742134005638, b=0.46607926214440526, count=1
# break! k1=Calliance_1_270, k2=Calliance_1_347, m=0.16786322651943164, b=-0.33003439831094156, count=1
# break! k1=Calliance_1_270, k2=Calliance_1_356, m=-8.429305304748994e+195, b=2.770015010297752e+195, count=9
# break! k1=Calliance_1_270, k2=Calliance_1_371, m=0.049918939477197465, b=1.1302068434500656, count=1
# break! k1=Calliance_1_270, k2=Calliance_1_419, m=-2.1167501696360683e+171, b=-2.0473104869637763e+172, count=11
# break! k1=Calliance_1_270, k2=Calliance_1_441, m=-0.01785185586159313, b=2.786338615591285, count=3
# break! k1=Calliance_1_270, k2=Calliance_1_52, m=0.03983342140214342, b=1.3048418441594347, count=1
# break! k1=Calliance_1_270, k2=Calliance_1_53, m=0.11726072546751402, b=0.048756649576073084, count=1
# break! k1=Calliance_1_275, k2=Calliance_1_28, m=0.11024351170127435, b=0.10197554312262841, count=4
# break! k1=Calliance_1_275, k2=Calliance_1_282, m=-1.1243868957898121e+215, b=3.021770961579864e+214, count=13
# break! k1=Calliance_1_275, k2=Calliance_1_304, m=0.11965535071383936, b=0.3607720599536668, count=2
# break! k1=Calliance_1_275, k2=Calliance_1_347, m=0.07067028006091972, b=1.7769156002603552, count=2
# break! k1=Calliance_1_275, k2=Calliance_1_356, m=0.12063838513298229, b=0.3842068742820223, count=2
# break! k1=Calliance_1_275, k2=Calliance_1_371, m=-2716232.2943500546, b=136134099.3217003, count=5
# break! k1=Calliance_1_275, k2=Calliance_1_419, m=0.1212978487102511, b=-0.3835725847221765, count=1
# break! k1=Calliance_1_275, k2=Calliance_1_441, m=-7.304112689944458e+263, b=9.104586038620023e+264, count=10
# break! k1=Calliance_1_275, k2=Calliance_1_52, m=153212513.05166143, b=-767594690.3868366, count=7
# break! k1=Calliance_1_275, k2=Calliance_1_53, m=0.1250610487693526, b=0.2706798726206995, count=2
# break! k1=Calliance_1_28, k2=Calliance_1_282, m=0.20296975900893827, b=-1.2519521975045547, count=1
# break! k1=Calliance_1_28, k2=Calliance_1_304, m=0.09633569702976467, b=0.2954341423587127, count=1
# break! k1=Calliance_1_28, k2=Calliance_1_347, m=9421.387870743965, b=-29771.585396668906, count=5
# break! k1=Calliance_1_28, k2=Calliance_1_356, m=-8.055163885676753e+218, b=2.58711606223396e+218, count=9
# break! k1=Calliance_1_28, k2=Calliance_1_371, m=0.05244848910162484, b=1.007257307692907, count=0
# break! k1=Calliance_1_28, k2=Calliance_1_419, m=2.6380024493138324e+180, b=-3.324174994662372e+181, count=8
# break! k1=Calliance_1_28, k2=Calliance_1_441, m=-0.011471751654150698, b=2.8488481016171416, count=3
# break! k1=Calliance_1_28, k2=Calliance_1_52, m=0.04656071654328211, b=1.1057317794702557, count=1
# break! k1=Calliance_1_28, k2=Calliance_1_53, m=0.15329318886098042, b=-0.34903810632490767, count=1
# break! k1=Calliance_1_282, k2=Calliance_1_304, m=-0.01993322050055234, b=31.182345985958754, count=6
# break! k1=Calliance_1_282, k2=Calliance_1_347, m=-5.622121657955608e+174, b=7.069345150439156e+173, count=12
# break! k1=Calliance_1_282, k2=Calliance_1_356, m=38363.6908556484, b=-192202.0902370356, count=5
# break! k1=Calliance_1_282, k2=Calliance_1_371, m=-0.019402784329241817, b=30.861869837985097, count=7
# break! k1=Calliance_1_282, k2=Calliance_1_419, m=1.4619589305740893e+282, b=-1.4619601326440862e+283, count=12
# break! k1=Calliance_1_282, k2=Calliance_1_441, m=349361030.79904884, b=-13908313826.679447, count=9
# break! k1=Calliance_1_282, k2=Calliance_1_52, m=-1.4417557078456843e+204, b=3.618806826547263e+205, count=7
# break! k1=Calliance_1_282, k2=Calliance_1_53, m=900502344.3472155, b=-9005023443.494822, count=6
# break! k1=Calliance_1_304, k2=Calliance_1_347, m=0.02972847414977168, b=5.929253489379313, count=4
# break! k1=Calliance_1_304, k2=Calliance_1_356, m=0.12252707731486309, b=0.3208811563260743, count=3
# break! k1=Calliance_1_304, k2=Calliance_1_371, m=-190195.68776592021, b=151015375.94013968, count=29
# break! k1=Calliance_1_304, k2=Calliance_1_419, m=461618.69411158893, b=-2313573.9403302395, count=7
# break! k1=Calliance_1_304, k2=Calliance_1_441, m=-1.5956254906492976e+173, b=2.967416861923635e+173, count=9
# break! k1=Calliance_1_304, k2=Calliance_1_52, m=-4.8757497110853766e+194, b=1.2321315267053362e+193, count=11
# break! k1=Calliance_1_304, k2=Calliance_1_53, m=0.13161227596668634, b=0.2037870550345231, count=2
# break! k1=Calliance_1_347, k2=Calliance_1_356, m=0.11739272645888868, b=-0.0037903164101016212, count=1
# break! k1=Calliance_1_347, k2=Calliance_1_371, m=1762228.7077951329, b=-139978800.99671575, count=8
# break! k1=Calliance_1_347, k2=Calliance_1_419, m=-7.859318321336728e+192, b=1.9741698060405124e+192, count=12
# break! k1=Calliance_1_347, k2=Calliance_1_441, m=-26915022.780877974, b=1071506408.5545919, count=5
# break! k1=Calliance_1_347, k2=Calliance_1_52, m=65672036.98886428, b=-1313440739.7713194, count=6
# break! k1=Calliance_1_347, k2=Calliance_1_53, m=-7.115551495046976e+247, b=1.419265457489778e+247, count=10
# break! k1=Calliance_1_356, k2=Calliance_1_371, m=0.040867877108694585, b=1.6903379569153114, count=2
# break! k1=Calliance_1_356, k2=Calliance_1_419, m=-6.215732979173893e+286, b=8.099187731326615e+287, count=8
# break! k1=Calliance_1_356, k2=Calliance_1_441, m=-0.004149322564422502, b=0.3870541846202143, count=5
# break! k1=Calliance_1_356, k2=Calliance_1_52, m=0.017633056098748722, b=2.0214740563858387, count=1
# break! k1=Calliance_1_356, k2=Calliance_1_53, m=0.06719718084680834, b=0.9853755003452822, count=0
# break! k1=Calliance_1_371, k2=Calliance_1_419, m=0.07077566945119745, b=0.3007266870864754, count=1
# break! k1=Calliance_1_371, k2=Calliance_1_441, m=2.780172878673585e+302, b=-8.122992669936817e+303, count=10
# break! k1=Calliance_1_371, k2=Calliance_1_52, m=0.05680641892466555, b=0.8338114651145138, count=1
# break! k1=Calliance_1_371, k2=Calliance_1_53, m=0.04130460078413925, b=1.6585086320171776, count=2
# break! k1=Calliance_1_419, k2=Calliance_1_441, m=0.02412686466372669, b=1.1630816153405463, count=1
# break! k1=Calliance_1_419, k2=Calliance_1_52, m=0.10024035772996438, b=-0.15121977779185264, count=1
# break! k1=Calliance_1_419, k2=Calliance_1_53, m=-1.2648116730726213e+230, b=-2.5245741977497423e+230, count=10
# break! k1=Calliance_1_441, k2=Calliance_1_52, m=-1608605.894602658, b=101496169.27380334, count=8
# break! k1=Calliance_1_441, k2=Calliance_1_53, m=0.14083855775010207, b=-11.158480197538363, count=14
# break! k1=Calliance_1_52, k2=Calliance_1_53, m=-2351.026899972751, b=296229.4475516998, count=14
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:202: RuntimeWarning: invalid value encountered in greater
#   m_list_adopted = m_list[(0 < m_list) & (m_list < 0.2) & (0 < b_list) & (b_list < 3)]
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:202: RuntimeWarning: invalid value encountered in less
#   m_list_adopted = m_list[(0 < m_list) & (m_list < 0.2) & (0 < b_list) & (b_list < 3)]
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:203: RuntimeWarning: invalid value encountered in greater
#   b_list_adopted = b_list[(0 < m_list) & (m_list < 0.2) & (0 < b_list) & (b_list < 3)]
# C:\Users\02217013\Documents\GitHub\PPRT\src\Analyze\..\calc_BVI.py:203: RuntimeWarning: invalid value encountered in less
#   b_list_adopted = b_list[(0 < m_list) & (m_list < 0.2) & (0 < b_list) & (b_list < 3)]

# %%
import itertools

def move_sympyplot_to_axis(p, ax):
    backend = p.backend(p)
    backend.ax = ax
    backend.process_series()
    backend.ax.spines["right"].set_color("none")
    backend.ax.spines["bottom"].set_position("zero")
    backend.ax.spines["top"].set_color("none")
    plt.close(backend.fig)
    

# 二つごとに組み合わせの引き算をプロット。
m, b = symbols("m b")

for combi_group in itertools.combinations(the_df.groupby("ID"), 2):
    
    key_1, group_1 = combi_group[0]
    key_2, group_2 = combi_group[1]
    
    Swirr_1 = 1/ (group_1.T2 * m + b)
    Swirr_2 = 1/ (group_2.T2 * m + b)
    
    f_1 = np.dot(group_1.Por, Swirr_1) - group_1.BVI_Por_cum.iloc[-1]
    f_2 = np.dot(group_2.Por, 1/ (group_2.T2 * m + b)) - group_2.BVI_Por_cum.iloc[-1]
    print(key_1, key_2)
    
    # f(x, y)を図示する
    p_1 = plot_implicit(f_1, (m, 0, 1), (b, 0, 2), show=False)
    p_2 = plot_implicit(f_2, (m, 0, 1), (b, 0, 2), show=False)
    
    fig, ax = plt.subplots()
    move_sympyplot_to_axis(p_1, ax)
    move_sympyplot_to_axis(p_2, ax)
    plt.show()
# Out:
# Calliance_1_142 Calliance_1_143
# Calliance_1_142 Calliance_1_148
# Calliance_1_142 Calliance_1_22
# Calliance_1_142 Calliance_1_225
# Calliance_1_142 Calliance_1_230
# Calliance_1_142 Calliance_1_239
# Calliance_1_142 Calliance_1_24
# Calliance_1_142 Calliance_1_270
# Calliance_1_142 Calliance_1_275
# Calliance_1_142 Calliance_1_28
# Calliance_1_142 Calliance_1_282
# Calliance_1_142 Calliance_1_304
# Calliance_1_142 Calliance_1_347
# Calliance_1_142 Calliance_1_356
# Calliance_1_142 Calliance_1_371
# Calliance_1_142 Calliance_1_419
# Calliance_1_142 Calliance_1_441
# Calliance_1_142 Calliance_1_52
# Calliance_1_142 Calliance_1_53
# Calliance_1_143 Calliance_1_148
# Calliance_1_143 Calliance_1_22
# Calliance_1_143 Calliance_1_225
# Calliance_1_143 Calliance_1_230
# Calliance_1_143 Calliance_1_239
# Calliance_1_143 Calliance_1_24
# Calliance_1_143 Calliance_1_270
# Calliance_1_143 Calliance_1_275
# Calliance_1_143 Calliance_1_28
# Calliance_1_143 Calliance_1_282
# Calliance_1_143 Calliance_1_304
# Calliance_1_143 Calliance_1_347
# Calliance_1_143 Calliance_1_356
# Calliance_1_143 Calliance_1_371
# Calliance_1_143 Calliance_1_419
# Calliance_1_143 Calliance_1_441
# Calliance_1_143 Calliance_1_52
# Calliance_1_143 Calliance_1_53
# Calliance_1_148 Calliance_1_22
# Calliance_1_148 Calliance_1_225
# Calliance_1_148 Calliance_1_230
# Calliance_1_148 Calliance_1_239
# Calliance_1_148 Calliance_1_24
# Calliance_1_148 Calliance_1_270
# Calliance_1_148 Calliance_1_275
# Calliance_1_148 Calliance_1_28
# Calliance_1_148 Calliance_1_282
# Calliance_1_148 Calliance_1_304
# Calliance_1_148 Calliance_1_347
# Calliance_1_148 Calliance_1_356
# Calliance_1_148 Calliance_1_371
# Calliance_1_148 Calliance_1_419
# Calliance_1_148 Calliance_1_441
# Calliance_1_148 Calliance_1_52
# Calliance_1_148 Calliance_1_53
# Calliance_1_22 Calliance_1_225
# Calliance_1_22 Calliance_1_230
# Calliance_1_22 Calliance_1_239
# Calliance_1_22 Calliance_1_24
# Calliance_1_22 Calliance_1_270
# Calliance_1_22 Calliance_1_275
# Calliance_1_22 Calliance_1_28
# Calliance_1_22 Calliance_1_282
# Calliance_1_22 Calliance_1_304
# Calliance_1_22 Calliance_1_347
# Calliance_1_22 Calliance_1_356
# Calliance_1_22 Calliance_1_371
# Calliance_1_22 Calliance_1_419
# Calliance_1_22 Calliance_1_441
# Calliance_1_22 Calliance_1_52
# Calliance_1_22 Calliance_1_53
# Calliance_1_225 Calliance_1_230
# Calliance_1_225 Calliance_1_239
# Calliance_1_225 Calliance_1_24
# Calliance_1_225 Calliance_1_270
# Calliance_1_225 Calliance_1_275
# Calliance_1_225 Calliance_1_28
# Calliance_1_225 Calliance_1_282
# Calliance_1_225 Calliance_1_304
# Calliance_1_225 Calliance_1_347
# Calliance_1_225 Calliance_1_356
# Calliance_1_225 Calliance_1_371
# Calliance_1_225 Calliance_1_419
# Calliance_1_225 Calliance_1_441
# Calliance_1_225 Calliance_1_52
# Calliance_1_225 Calliance_1_53
# Calliance_1_230 Calliance_1_239
# Calliance_1_230 Calliance_1_24
# Calliance_1_230 Calliance_1_270
# Calliance_1_230 Calliance_1_275
# Calliance_1_230 Calliance_1_28
# Calliance_1_230 Calliance_1_282
# Calliance_1_230 Calliance_1_304
# Calliance_1_230 Calliance_1_347
# Calliance_1_230 Calliance_1_356
# Calliance_1_230 Calliance_1_371
# Calliance_1_230 Calliance_1_419
# Calliance_1_230 Calliance_1_441
# Calliance_1_230 Calliance_1_52
# Calliance_1_230 Calliance_1_53
# Calliance_1_239 Calliance_1_24
# Calliance_1_239 Calliance_1_270
# Calliance_1_239 Calliance_1_275
# Calliance_1_239 Calliance_1_28
# Calliance_1_239 Calliance_1_282
# Calliance_1_239 Calliance_1_304
# Calliance_1_239 Calliance_1_347
# Calliance_1_239 Calliance_1_356
# Calliance_1_239 Calliance_1_371
# Calliance_1_239 Calliance_1_419
# Calliance_1_239 Calliance_1_441
# Calliance_1_239 Calliance_1_52
# Calliance_1_239 Calliance_1_53
# Calliance_1_24 Calliance_1_270
# Calliance_1_24 Calliance_1_275
# Calliance_1_24 Calliance_1_28
# Calliance_1_24 Calliance_1_282
# Calliance_1_24 Calliance_1_304
# Calliance_1_24 Calliance_1_347
# Calliance_1_24 Calliance_1_356
# Calliance_1_24 Calliance_1_371
# Calliance_1_24 Calliance_1_419
# Calliance_1_24 Calliance_1_441
# Calliance_1_24 Calliance_1_52
# Calliance_1_24 Calliance_1_53
# Calliance_1_270 Calliance_1_275
# Calliance_1_270 Calliance_1_28
# Calliance_1_270 Calliance_1_282
# Calliance_1_270 Calliance_1_304
# Calliance_1_270 Calliance_1_347
# Calliance_1_270 Calliance_1_356
# Calliance_1_270 Calliance_1_371
# Calliance_1_270 Calliance_1_419
# Calliance_1_270 Calliance_1_441
# Calliance_1_270 Calliance_1_52
# Calliance_1_270 Calliance_1_53
# Calliance_1_275 Calliance_1_28
# Calliance_1_275 Calliance_1_282
# Calliance_1_275 Calliance_1_304
# Calliance_1_275 Calliance_1_347
# Calliance_1_275 Calliance_1_356
# Calliance_1_275 Calliance_1_371
# Calliance_1_275 Calliance_1_419
# Calliance_1_275 Calliance_1_441
# Calliance_1_275 Calliance_1_52
# Calliance_1_275 Calliance_1_53
# Calliance_1_28 Calliance_1_282
# Calliance_1_28 Calliance_1_304
# Calliance_1_28 Calliance_1_347
# Calliance_1_28 Calliance_1_356
# Calliance_1_28 Calliance_1_371
# Calliance_1_28 Calliance_1_419
# Calliance_1_28 Calliance_1_441
# Calliance_1_28 Calliance_1_52
# Calliance_1_28 Calliance_1_53
# Calliance_1_282 Calliance_1_304
# Calliance_1_282 Calliance_1_347
# Calliance_1_282 Calliance_1_356
# Calliance_1_282 Calliance_1_371
# Calliance_1_282 Calliance_1_419
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1fef24d792f0> in <module>
#      31
#      32     fig, ax = plt.subplots()
# ---> 33     move_sympyplot_to_axis(p_1, ax)
#      34     move_sympyplot_to_axis(p_2, ax)
#      35     plt.show()
#
# <ipython-input-11-1fef24d792f0> in move_sympyplot_to_axis(p, ax)
#       4     backend = p.backend(p)
#       5     backend.ax = ax
# ----> 6     backend.process_series()
#       7     backend.ax.spines["right"].set_color("none")
#       8     backend.ax.spines["bottom"].set_position("zero")
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\plotting\plot.py in process_series(self)
#     928                 self.ax.spines['left'].set_smart_bounds(False)
#     929                 self.ax.spines['bottom'].set_smart_bounds(False)
# --> 930                 points = s.get_raster()
#     931                 if len(points) == 2:
#     932                     #interval math plotting
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\plotting\plot_implicit.py in get_raster(self)
#      86
#      87         if self.use_interval_math:
# ---> 88             return self._get_raster_interval(func)
#      89         else:
#      90             return self._get_meshes_grid()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\plotting\plot_implicit.py in _get_raster_interval(self, func)
#     150
#     151         while k >= 0 and len(interval_list):
# --> 152             interval_list, plot_list_temp = refine_pixels(interval_list)
#     153             plot_list.extend(plot_list_temp)
#     154             k = k - 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\plotting\plot_implicit.py in refine_pixels(interval_list)
#     128                 intervalx = intervals[0]
#     129                 intervaly = intervals[1]
# --> 130                 func_eval = func(intervalx, intervaly)
#     131                 #The expression is valid in the interval. Change the contour
#     132                 #array values to 1.
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, *args, **kwargs)
#     314
#     315     def __call__(self, *args, **kwargs):
# --> 316         return self.lambda_func(*args, **kwargs)
#     317
#     318
#
# <string> in <lambda>(x0, x1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\plotting\intervalmath\interval_arithmetic.py in __mul__(self, other)
#     291                 end = max(inters)
#     292                 return interval(start, end)
# --> 293         elif isinstance(other, (int, float)):
#     294             return interval(self.start*other, self.end*other, is_valid=self.is_valid)
#     295         else:
#
# KeyboardInterrupt:
